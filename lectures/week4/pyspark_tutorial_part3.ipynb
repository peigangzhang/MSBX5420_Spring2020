# %% [markdown]
# # Create SparkContext

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# # Create pair RDD from RDD of loading text file

# %%
import random

input_data_path = '../week1/big_data_intro.txt'
text_file = sc.textFile(input_data_path)

word_to_length_pair_rdd = text_file.flatMap(lambda line: line.split(" ")) \
.map(lambda word: (word, random.random()))

print(word_to_length_pair_rdd.take(10))
# Out:
# [('Introduction', 0.06659323731178812), ('Big', 0.6019054800165461), ('data', 0.6316725022310598), ('is', 0.6048955313938121), ('a', 0.19320798564262665), ('blanket', 0.4760673338516238), ('term', 0.4073858823715758), ('for', 0.09332026308071528), ('the', 0.38652625320067413), ('non-traditional', 0.23451162109608492)]

# %% [markdown]
# # Demo tranformation - keys()

# %%
word_to_length_pair_keys_rdd = word_to_length_pair_rdd.keys()

print(word_to_length_pair_keys_rdd.take(10))
# Out:
# ['Introduction', 'Big', 'data', 'is', 'a', 'blanket', 'term', 'for', 'the', 'non-traditional']

# %% [markdown]
# # Demo transformation - values()

# %%
word_to_length_pair_values_rdd = word_to_length_pair_rdd.values()
print(word_to_length_pair_values_rdd.take(10))
# Out:
# [0.5262972192425175, 0.275105530725299, 0.014762469849213034, 0.16842970170760163, 0.580890472398784, 0.5977490094390006, 0.3918114982918476, 0.3702962622707826, 0.6666599819830247, 0.42069137597758766]

# %%
word_to_length_pair_group_rdd = word_to_length_pair_rdd.groupByKey()

group_result = word_to_length_pair_group_rdd.take(10)
for key, values in group_result:
    print('key = {}'.format(key))
    for value in values:
        print(value)
# Out:
# key = is
# 0.3223510764478078
# 0.5717124043578006
# 0.837033195438256
# 0.5103507376523803
# 0.7403284265237835
# 0.17971275848127566
# 0.4255501790830092
# 0.4880873618646695
# 0.9225068862863768
# 0.9418359557605199
# 0.9857264232616598
# 0.09882430563342881
# 0.6570156796419482
# 0.9754607769813225
# 0.48813534873125997
# 0.6977051974090042
# 0.44089059806923525
# 0.2869723935063746
# 0.15237839086027527
# 0.7986694972768231
# 0.09133793665709189
# 0.4237933360811421
# 0.720158640563486
# 0.9039725282102399
# 0.4534281566085403
# 0.7241224525286324
# 0.5680177913782257
# 0.5828107610420503
# 0.9119873796002588
# 0.05288298412099712
# 0.29741046010966576
# 0.8220375998403998
# 0.5145568835493479
# 0.9902379472467424
# 0.9130307309453848
# 0.09457951000786324
# 0.8942610898566419
# 0.8983915422823726
# 0.2309145870646374
# 0.9145325347519898
# 0.2358118805095799
# 0.6364613175100698
# 0.6550697272269663
# 0.8233352116211494
# 0.8478583545206029
# 0.2549151448575263
# 0.07302734880220796
# 0.5179177393382548
# 0.4546248891657859
# 0.26251809650363545
# 0.055487403482789355
# 0.2925391347167693
# 0.3180993426076273
# 0.694781116222873
# 0.4995160980236013
# 0.34322631824943817
# 0.5628677326226125
# 0.8529093227673693
# 0.9685354982264183
# key = term
# 0.2181539984482559
# 0.1624141279392669
# 0.16783325069075095
# 0.4104370198894065
# 0.41607981522451387
# 0.9777316079166118
# 0.9974949541955322
# key = non-traditional
# 0.23403639194263381
# key = needed
# 0.476498051194435
# 0.02809069689210597
# key = gather
# 0.7348965431959211
# 0.8087774915786958
# key = organize
# 0.9604546214931794
# 0.36938357029840707
# key = process
# 0.4218503213665197
# 0.19411599516600508
# 0.21352326429088797
# 0.12231950223921195
# 0.5012723369004637
# 0.5403500204111054
# 0.5150395045204399
# 0.2340248271990769
# 0.3944736655550394
# 0.6060553789311522
# 0.1433334006696999
# 0.6351320290460982
# 0.9868350864185204
# 0.5470400681732642
# 0.8752768395561565
# key = large
# 0.9299808751331851
# 0.10150347351195066
# 0.608940821164907
# 0.7176125419549022
# 0.2311759782626316
# 0.8764464704420031
# 0.05340406735570069
# 0.23018964128610087
# 0.9253804220548598
# 0.14764725032936887
# 0.17176557553108374
# 0.22640210362184976
# 0.11037917454103452
# 0.9412683632718964
# 0.7631507387736532
# 0.7273984939155463
# 0.9925544798894861
# 0.7992362000686009
# key = datasets
# 0.4309621235703702
# 0.17204385476463957
# 0.5221580842429154
# 0.7167354383931965
# 0.7504674351582024
# 0.020961528461386658
# 0.8303707848580083
# 0.9575405535416395
# 0.9208711156089361
# 0.19389234229854913
# 0.20117823787816547
# key = of
# 0.7253284178508175
# 0.6572531198332483
# 0.5354904330528044
# 0.6076831280798368
# 0.9990360633840963
# 0.5950836757528236
# 0.4778790006759489
# 0.3666250446859254
# 0.8505140455794863
# 0.3643107752687952
# 0.07032434065384585
# 0.6091012578978404
# 0.6332361947200814
# 0.7818986910749549
# 0.17494405276355485
# 0.9274977188299999
# 0.640191443759438
# 0.8958450598458912
# 0.8622394502864462
# 0.3958352071035879
# 0.5931750674213914
# 0.23495812999012544
# 0.31257591370048954
# 0.036932259234353615
# 0.24364762786843286
# 0.7960873543035676
# 0.24230783189513194
# 0.6814848744429415
# 0.9694145414231966
# 0.34237843053583583
# 0.9780166443535305
# 0.7848823422745891
# 0.9149423794049386
# 0.2717752386125941
# 0.7647853405896426
# 0.6342934120389676
# 0.6087161603472385
# 0.4244491266527206
# 0.5466811411285827
# 0.2906615090009882
# 0.19560361148098182
# 0.7179763137225067
# 0.1315000244988891
# 0.550764841302988
# 0.09712488113285767
# 0.10297461651877626
# 0.7342890964823422
# 0.807056957433194
# 0.5685642213427523
# 0.29761544021336694
# 0.22674195977443234
# 0.21489895771110923
# 0.8674623961580599
# 0.5822742446199612
# 0.12141623953448799
# 0.7266327340290019
# 0.6959116473628325
# 0.7828481521528432
# 0.8204394122248265
# 0.1568053134991878
# 0.3346187203034485
# 0.9608659544057608
# 0.24792200983582646
# 0.02617154300340152
# 0.1954072376643271
# 0.11229154839305966
# 0.48658547044803635
# 0.5829933591523182
# 0.9121525884945013
# 0.7789092333158038
# 0.2633120521558786
# 0.8774187786522061
# 0.5937333998937621
# 0.007931710975090267
# 0.12019094905380923
# 0.30922372582615976
# 0.18141926990744217
# 0.18616658564408006
# 0.043472888503212626
# 0.7996722887475026
# 0.5852134824294207
# 0.9317104066694935
# 0.3350334619091051
# 0.5256849199293872
# 0.4055639647405236
# 0.2947639990623071
# 0.15232539207964568
# 0.724596139507988
# 0.6728690239323077
# 0.6632666886534015
# 0.9255718307784879
# 0.14620328224135792
# 0.13099328828672296
# 0.10064725848093747
# 0.3482464650587286
# 0.22344202385306966
# 0.8760343675278427
# 0.401061031758402
# 0.09543925404751707
# 0.705937556284778
# 0.7343193214901896
# 0.320719473458844
# 0.6159911503623614
# 0.5733198492786896
# 0.3693382128211238
# 0.2005980667704269
# 0.4058474411479819
# 0.06626767282010115
# 0.8727910980477988
# 0.7583865255943396
# 0.28376453304483784

# %%
word_to_length_pair_reduce_rdd = word_to_length_pair_rdd.reduceByKey(lambda a, b: a + b)
print(word_to_length_pair_reduce_rdd.take(10))
# Out:
# [('is', 31.312902250069808), ('term', 2.940584201660485), ('non-traditional', 0.0302325736417971), ('needed', 1.0367739191795897), ('gather', 1.383135494575228), ('organize', 1.284718689328098), ('process', 8.844317496688344), ('large', 9.955189682610467), ('datasets', 4.575313446701122), ('of', 55.1374901600131)]

# %%
bigdata_word_to_count_pair_rdd = sc.textFile('../week1/big_data_intro.txt') \
    .flatMap(lambda line: line.split(" ")) \
    .map(lambda word: (word, 1)) \
    .reduceByKey(lambda a, b: a + b)
#bigdata_word_to_count_pair_rdd = bigdata_word_to_count_pair_rdd.repartition(len(bigdata_word_to_count_pair_rdd.collect()))

print(bigdata_word_to_count_pair_rdd.take(10))

hamlet_word_to_count_pair_rdd = sc.textFile('./hamlet.txt') \
    .flatMap(lambda line: line.split(" ")) \
    .map(lambda word: (word, 1)) \
    .reduceByKey(lambda a, b: a + b)
#hamlet_word_to_count_pair_rdd = hamlet_word_to_count_pair_rdd.repartition(len(hamlet_word_to_count_pair_rdd.collect()))

print(hamlet_word_to_count_pair_rdd.take(10))
# Out:
# [('is', 59), ('term', 7), ('non-traditional', 1), ('needed', 2), ('gather', 2), ('organize', 2), ('process', 15), ('large', 18), ('datasets', 11), ('of', 111)]
# [('', 186), ('The', 149), ('Tragedy', 1), ('of', 623), ('Prince', 1), ('Denmark', 9), ('Shakespeare', 1), ('|', 2), ('Entire', 1), ('ACT', 5)]

# %%
bigdata_join_hamlet_rdd = bigdata_word_to_count_pair_rdd.join(hamlet_word_to_count_pair_rdd)
print(bigdata_join_hamlet_rdd.collect())
# Out:
# [('is', (59, 291)), ('term', (7, 2)), ('gather', (2, 1)), ('process', (15, 1)), ('large', (18, 1)), ('of', (111, 623)), ('working', (4, 1)), ('power', (1, 7)), ('single', (7, 2)), ('new', (4, 2)), ('this', (13, 204)), ('in', (41, 387)), ('years', (1, 1)), ('', (38, 186)), ('we', (7, 107)), ('common', (4, 5)), ('subject', (1, 2)), ('take', (3, 26)), ('look', (2, 16)), ('at', (8, 75)), ('used', (13, 1)), ('What', (2, 77)), ('down', (2, 11)), ('business', (2, 8)), ('use', (2, 14)), ('quite', (2, 3)), ('mind', (2, 7)), ('are', (35, 119)), ('means', (5, 14)), ('may', (2, 58)), ('The', (18, 149)), ('as', (17, 146)), ('speed', (3, 3)), ('must', (1, 53)), ('stage', (2, 2)), ('when', (5, 28)), ('would', (2, 63)), ('possible', (2, 1)), ('known', (2, 5)), ('three', (3, 9)), ('make', (5, 45)), ('different', (6, 1)), ('other', (9, 11)), ('These', (5, 7)), ('larger', (1, 1)), ('than', (3, 38)), ('demands', (2, 1)), ('more', (11, 69)), ('thought', (1, 6)), ('work', (9, 5)), ('exceed', (1, 1)), ('capable', (1, 1)), ('into', (11, 26)), ('Another', (5, 6)), ('way', (4, 7)), ('moves', (1, 2)), ('near', (2, 6)), ('instant', (1, 4)), ('away', (1, 8)), ('guard', (1, 1)), ('against', (1, 18)), ('both', (2, 17)), ('quality', (6, 3)), ('like', (14, 68)), ('seeks', (1, 1)), ('where', (1, 28)), ('Rich', (1, 1)), ('enter', (1, 3)), ('already', (2, 2)), ('raw', (8, 1)), ('state', (3, 6)), ('have', (4, 158)), ('though', (1, 16)), ('these', (7, 38)), ('rather', (1, 3)), ('low', (1, 1)), ('there', (2, 41)), ('below', (1, 2)), ('true', (1, 14)), ('four', (1, 4)), ('an', (6, 49)), ('high', (3, 2)), ('needs', (1, 7)), ('clear', (1, 1)), ('benefit', (1, 1)), ('but', (4, 148)), ('fault', (2, 4)), ('prevent', (1, 1)), ('machine', (3, 1)), ('depends', (1, 1)), ('heavily', (1, 1)), ('far', (1, 10)), ('One', (3, 5)), ('help', (1, 4)), ('end', (1, 9)), ('sometimes', (2, 4)), ('out', (1, 37)), ('certain', (3, 3)), ('kept', (1, 4)), ('further', (1, 9)), ('simple', (1, 1)), ('best', (4, 9)), ('serve', (1, 2)), ('read', (1, 1)), ('Once', (1, 2)), ('perhaps', (1, 3)), ('very', (2, 56)), ('good', (1, 73)), ('above', (2, 2)), ('themselves', (1, 4)), ('points', (1, 1)), ('them', (3, 42)), ('helpful', (1, 1)), ('cannot', (1, 23)), ('due', (2, 1)), ('sets', (4, 2)), ('started', (1, 1)), ('spirit', (1, 8)), ('mining', (2, 1)), ('broad', (3, 2)), ('It', (3, 55)), ('set', (3, 20)), ('spoken', (1, 1)), ('project', (1, 1)), ('was', (1, 67)), ('run', (1, 1)), ('huge', (1, 1)), ('fed', (2, 2)), ('behavior', (1, 1)), ('model', (1, 1)), ('move', (1, 5)), ('deal', (1, 1)), ('a', (66, 450)), ('for', (42, 164)), ('the', (145, 988)), ('and', (103, 693)), ('to', (87, 604)), ('from', (18, 83)), ('While', (9, 1)), ('with', (26, 220)), ('that', (32, 228)), ('or', (19, 78)), ('not', (6, 259)), ('scale', (5, 2)), ('has', (4, 15)), ('greatly', (1, 1)), ('In', (6, 36)), ('article', (1, 1)), ('will', (5, 133)), ('talk', (4, 2)), ('about', (6, 13)), ('on', (18, 100)), ('level', (3, 1)), ('define', (3, 1)), ('you', (2, 356)), ('might', (5, 28)), ('come', (1, 47)), ('while', (2, 6)), ('We', (1, 29)), ('also', (7, 1)), ('some', (6, 52)), ('being', (6, 8)), ('Is', (1, 27)), ('An', (1, 7)), ('exact', (1, 1)), ('because', (4, 1)), ('it', (14, 270)), ('With', (2, 43)), ('too', (1, 33)), ('This', (16, 45)), ('Why', (1, 21)), ('Are', (1, 8)), ('same', (3, 10)), ('any', (3, 17)), ('be', (28, 192)), ('dealt', (1, 1)), ('each', (6, 8)), ('present', (2, 3)), ('most', (7, 70)), ('first', (1, 12)), ('what', (3, 110)), ('became', (1, 1)), ('helps', (1, 1)), ('can', (33, 32)), ('which', (11, 35)), ('life', (2, 12)), ('becomes', (3, 2)), ('breaking', (2, 1)), ('important', (5, 1)), ('through', (4, 8)), ('often', (11, 2)), ('time', (4, 27)), ('gain', (2, 2)), ('understanding', (1, 2)), ('driven', (1, 1)), ('many', (5, 17)), ('order', (1, 2)), ('keep', (1, 16)), ('up', (4, 26)), ('along', (1, 2)), ('wide', (3, 2)), ('their', (5, 54)), ('relative', (1, 1)), ('its', (3, 2)), ('coming', (1, 4)), ('by', (13, 96)), ('all', ( ...
